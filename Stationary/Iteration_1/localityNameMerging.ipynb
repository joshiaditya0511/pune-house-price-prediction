# %%
import json

# %% [markdown]
# # Merge 1

# %%
localityNameMerge_v1 = {
    #--- Kharadi and its smaller sub-areas ---
    "Kharadi": [
        "Kharadi Gaon, Kharadi",
        "Thite Nagar, Kharadi",
        "Ashoka Nagar, Kharadi",
        "Tukaram Nagar Kharadi",
        "Vitthal Nagar Kharadi",
        "Rakshak Nagar, Kharadi"
    ],
    
    #--- Wagholi ---
    "Wagholi": [
        "Kalubai Nagar Wagholi"
    ],
    
    #--- Wakad ---
    "Wakad": [
        "Bhumkar Nagar Wakad",
        "Kaspate Wasti"
    ],
    
    #--- Hinjewadi ---
    # Keep Phase 1, Phase 2, Phase 3, Marunji separate if you wish
    # because they each have substantial counts.
    # But here is an example of merging one smaller variant:
    "Hinjewadi": [
        "Hinjewadi Rajiv Gandhi Infotech Park, Hinjewadi"
    ],
    
    #--- Baner ---
    "Baner": [
        "Baner Road",
        "Baner Gaon, Baner",
        "Laxman Nagar Baner",
        "Veerbhadra Nagar, Baner",
        "Balewadi Phata, Baner",
        "Pan Card Club Road",
        "Baner Highway Side Rd"
    ],
    
    #--- Hadapsar ---
    "Hadapsar": [
        "Sasane Nagar, Hadapsar",
        "Malwadi Hadapsar",
        "Hadapsar Industrial Estate",
        "Hadapsar Gaon, Hadapsar",
        "North Hadapsar, Hadapsar",
        "Kale Padal, Hadapsar",
        "Satav Nagar"
    ],
    
    #--- Undri ---
    "Undri": [
        "Wadachi Wadi, Undri",
        "Kad Nagar, Undri",
        "Atur Nagar, Undri"
    ],
    
    #--- Kondhwa ---
    # Large enough to keep "Kondhwa BK" as separate if you wish;
    # But definitely merge small pockets like Kausar Baugh into Kondhwa.
    "Kondhwa": [
        "Kausar Baugh",
        "Tilekar Nagar, Kondhwa Budruk"
    ],
    
    #--- Balewadi ---
    "Balewadi": [
        "Patil Nagar Balewadi",
        "Balewadi Gaon, Balewadi",
        "Laxmi Nagar Balewadi"
    ],
    
    #--- Kothrud ---
    "Kothrud": [
        "Rambaug Colony, Kothrud",
        "Mahatma Society, Kothrud"
    ],
    
    #--- Dhayari ---
    "Dhayari": [
        "Dhayari Phata Road",
        "Dhayari Phata, Dhayari",
        "DSK Vishwa, Dhayari",
        "Mahadev Nagar Dhayari"
    ],
    
    #--- Mundhwa ---
    # Keep "Keshav Nagar Mundhwa" separate if large (354).
    "Mundhwa": [
        "Sasane Colony, Mundhwa"
    ],
    
    #--- Keshav Nagar Mundhwa ---
    "Keshav Nagar Mundhwa": [
        "Anand Nagar Keshav Nagar"
    ],
    
    #--- Narhe ---
    "Narhe": [
        "Manaji Nagar Narhe"
    ],
    
    #--- Lohegaon ---
    "Lohegaon": [
        "Adarsh Nagar Lohegaon"
        # "Dhanori Lohegaon Road" could go to Lohegaon or Dhanori,
        # but is often considered a boundary area
    ],
    
    #--- Magarpatta ---
    "Magarpatta": [
        "Phase 2 Magarpatta"
    ],
    
    #--- Dhanori ---
    "Dhanori": [
        "Dhanori Lohegaon Road"
    ],
    
    #--- Handewadi ---
    "Handewadi": [
        "Handewadi Road"
    ],
    
    #--- Mohammed Wadi ---
    "Mohammed Wadi": [
        "Mohamadwadi Settlement"
    ],
    
    #--- Bavdhan ---
    # "Bhugaon, Bavdhan" has 138, which you may choose to keep separate or merge.
    "Bavdhan": [
        "Chandani Chowk, Bavdhan",
        "Ram Nagar Bavdhan"
    ],
    
    #--- Wanowrie ---
    "Wanowrie": [
        "Wanawadi Gaon",
        "Clover Village, Wanawari",
        "Fatima Nagar Wanowrie",
        "Azad Nagar Wanowrie"
    ],
    
    #--- Katraj ---
    "Katraj": [
        "Sukhsagar Nagar Katraj",
        "Yewalewadi, Katraj",
        "Yewalewadi"
    ],
    
    #--- Pashan ---
    "Pashan": [
        "Pashan Sus Road"
    ],
    
    #--- Ambegaon ---
    # If "Ambegaon BK" (104) is considered large enough, keep it separate
    "Ambegaon": [
        "Ambegaon Pathar Road"
    ],
    
    #--- Manjri ---
    "Manjri, Manjri Budruk": [
        "Manjari Khurd"
    ],
    
    #--- Aundh ---
    "Aundh": [
        "Anand Park Aundh"
    ],
    
    #--- Kiwale, Dehu Road ---
    "Kiwale, Dehu Road": [
        "Adarsh Nagar Kiwale"
    ],
    
    #--- Ghorpadi ---
    "Ghorpadi": [
        "Uday Baug, Ghorpadi"
    ],
    
    #--- Market Yard / Gultekdi ---
    # There's a bit of ambiguity here. You could standardize everything
    # to "Market Yard, Gultekdi" or just "Gultekdi".
    "Market Yard, Gultekdi": [
        "Gultekadi",
        "Salisbury Park, Gultekdi"
    ],
}

# %%
with open('LocalitiesMerge/localityNameMerge_v1.json', 'w') as f:
    json.dump(localityNameMerge_v1, f, indent=4)

# %% [markdown]
# # Merge 2

# %%
localityNameMerge_v2 = {
    # Kharadi area
    'Kharadi': ['Tulaja Bhawani Nagar, Kharadi', 'Pandhari Nagar Kharadi'],
    
    # Baner area
    'Baner': ['Ram Nagar Baner', 'Baner Pashan Link Road'],
    
    # Lohegaon area
    'Lohegaon': ['Sathe Nagar, Lohegaon', 'Sant Nagar Lohegaon', 'Nimbalkar Nagar Lohegaon'],
    
    # Dhanori area
    'Dhanori': ['Gokul Nagar Dhanori', 'Munjaba Vasti, Dhanori', 'Parande Nagar, Dhanori', 
               'Madhav Nagar, Dhanori', 'Laxmi Nagar Dhanori', 'Siddartha Nagar Dhanori'],
    
    # Kondhwa area
    'Kondhwa': ['Kondhwa BK', 'Rajas Society, Kondhwa Budruk', 'Ambedkar Nagar Kondhwa', 
               'Meeta Nagar, Kondhwa'],
    
    # Mundhwa area (keeping Keshav Nagar Mundhwa separate due to high count)
    'Mundhwa': ['Kirtane Baug, Mundhwa', 'Koregaon Park Annexe, Mundhwa'],
    
    # Bavdhan area
    'Bavdhan': ['Bhugaon, Bavdhan', 'Mokai Vasti, Bavdhan', 'Pranjali Patil Nagar, Bavdhan'],
    
    # Pashan area
    'Pashan': ['Someshwarwadi, Pashan', 'Sutarwadi, Pashan', 'Pashan Gaon, Pashan'],
    
    # Kothrud area
    'Kothrud': ['Mayur Colony Kothrud', 'Dahanukar Colony, Kothrud', 'Bhusari Colony, Kothrud',
               'Rambaug Colony, Kothrud', 'Mahatma Society, Kothrud'],
    
    # Anand Nagar area
    'Anand Nagar': ['Manik Baug, Anand Nagar', 'Sun City, Anand Nagar'],
    
    # Dhayari area
    'Dhayari': ['Damodar Raykar Nagar, Dhayari', 'Benkar Nagar, Dhayari', 'Garmal, Dhayari'],
    
    # Tingre Nagar area
    'Tingre Nagar': ['Siddheshwar Nagar, Tingre Nagar', 'Adarsh Colony Tingre Nagar'],
    
    # Ravet area (keeping as separate entity due to high count)
    'Ravet, Pimpri Chinchwad': ['Ganesh Nagar Ravet', 'Sector 29 Ravet', 'Mukai Nagar Ravet'],
    
    # Talegaon area
    'Talegaon Dabhade': ['Varale Talegaon Dabhade', 'Yashwant Nagar Talegaon Dabhade'],
    
    # Viman Nagar area
    'Viman Nagar': ['Sakore Nagar, Viman Nagar', 'Clover Park, Viman Nagar'],
    
    # Sopan Baug
    'Sopan Baug': ['Sopan Baug Society, Ghorpadi'],
    
    # Peth areas (Old Pune city)
    'Kasba Peth': ['Bhavani Peth, Kasba Peth', 'Bhawani Peth'],
    'Narayan Peth': ['Shaniwar peth, Narayan Peth'],
    
    # Alandi area
    'Alandi, Kelgaon': ['Alandi Road', 'Dudulgaon, Alandi'],
    
    # Mohammed Wadi area
    'Mohammed Wadi': ['Dorabjee Paradise, Mohammed Wadi', 'Nyati County, Mohammed Wadi', 
                     'Mahadev Wadi Mohammed Wadi'],
    
    # Punawale area
    'Punawale, Pimpri Chinchwad': ['Vishnu Dev Nagar Punawale', 'Punvale Bazar'],
    
    # Pimple Saudagar area
    'Pimple Saudagar, Pimpri Chinchwad': ['Pimple Saudagar Gaon'],
    
    # Hinjewadi areas - keeping IT Park phases separate as they're significant
    'Hinjewadi': ['Hinjewadi Village', 'Hinjewadi Wakad Road'],
    
    # Tathawade area
    'Tathawade Pimpri Chinchwad': ['Tathawade Road', 'Ashok Nagar Tathawade'],
    
    # Pimpri area
    'Pimpri': ['Sant Tukaram Nagar Pimpri Colony'],
    
    # Chikhali area (consolidating both entries)
    'Chikhali, Pimpri Chinchwad': ['Chikhali', 'Jadhav Wadi Chikhali'],
    
    # Handewadi area
    'Handewadi': ['Pandhari Nagar Handewadi'],
    
    # Moshi area
    'Moshi': ['Moshi gaon, Pimpri Chinchwad'],
    
    # Undri area
    'Undri': ['Shree Siddhivinayak Meera, Undri'],
    
    # Mahalunge area (keeping Marunji separate due to substantial count)
    'Mahalunge': ['Mahalunge Ingale'],
    
    # Katraj area
    'Katraj': ['Gokul Nagar Katraj'],
    
    # Aundh area
    'Aundh': ['Aundh Gaon, Aundh', 'Aundh Baner Link Road'],
    
    # NIBM area
    'NIBM Road': ['NIBM Annexe Area'],
    
    # Manjri area
    'Manjri, Manjri Budruk': ['Manjri BK'],
    
    # Hadapsar area
    'Hadapsar': ['Gadital, Hadapsar'],
    
    # Dehu Road area
    'Dehu Road': ['Kiwale, Dehu Road', 'Mamurdi, Dehu Road'],
    
    # Ghorpadi area
    'Ghorpadi': ['Sopan Baug Society, Ghorpadi'],
    
    # Yerawada area
    'Yerawada, Airport Road': ['Shastrinagar Yerawada'],
    
    # Shankar Kalat Nagar area
    'Shankar Kalat Nagar': ['Choudhary Park Shankar Kalat Nagar'],
    
    # Ambegaon area
    'Ambegaon': ['Ambegaon BK'],
    
    # Wakad area (keeping separate from Hinjewadi despite proximity)
    'Wakad': [],
    
    # Airport Road consolidation
    'Airport Road': ['Vishrantwadi, Airport Road', 'Yerawada, Airport Road'],
    
    # Somatane/Somatne variations
    'Somatne Phata': ['Somatane'],
    
    # Vadgaon variations
    'Vadgaon BK': ['Vadgaon', 'Vadgaon Khurd'],
    
    # Parvati area
    'Parvati Paytha': ['Sahakar Nagar Parvati Paytha'],
}

# %%
with open('LocalitiesMerge/localityNameMerge_v2.json', 'w') as f:
    json.dump(localityNameMerge_v2, f, indent=4)

# %% [markdown]
# # Merge 3

# %%
localityNameMerge_v3 = {
    # Use the parent’s (higher‐count) name as the key and merge lower–count variants
    'Akurdi': ['Akurdi Gaothan'],
    'Mamurdi, Dehu Road': ['Dehu Road', 'Dehu', 'Sai Nagar Mamurdi'],
    'Vadgaon': ['Vadgaon', 'Wadgaon BK', 'Vadgaon Khurd', 'Vishnupuram Colony, Vadgaon Budruk'],
    'Kothrud': ['Mayur Colony Kothrud', 'Dahanukar Colony, Kothrud', 'Bhusari Colony, Kothrud', 'Ideal Colony, Kothrud'],
    'Anand Nagar, Sinhagad Road': ['Manik Baug, Anand Nagar', 'Sun City, Anand Nagar', 'Nimbaj Nagar, Anand Nagar', 'Niranjan Park, Anand Nagar'],
    'Ghorpadi': ['Balaji Nagar Ghorpadi', 'Ganesh Nagar Ghorpadi'],
    'Loni Kalbhor': ['Kadam Wasti Loni Kalbhor', 'Loni'],
    'Uruli Kanchan': ['Uruli Devachi'],
    'Tingre Nagar': ['Siddheshwar Nagar, Tingre Nagar', 'Adarsh Colony Tingre Nagar'],
    'Nigdi, Pimpri Chinchwad': ['Pradhikaran Nigdi'],
    'Sangamvadi': ['Bund Garden, Sangamvadi', 'Bund Garden Road'],
    'Nanded': ['Nanded Fata', 'Nande'],
    'Tathawade Road': ['Ashok Nagar Tathawade'],
    'Alandi Road': ['Dudulgaon, Alandi', 'Alandi Devachi', 'Alandi Markal Road'],
    'Jambhul': ['Jambhulwadi'],
    'Khadakwasla': ['Kolhewadi, Khadakwasla'],
    'Khed Shivapur': ['Khed Shivapur Kondanpur Road'],
    'Parvati Paytha': ['Sahakar Nagar Parvati Paytha', 'Sant Nagar Parvati Paytha'],
    'Dhanori': ['Munjaba Vasti, Dhanori', 'Laxmi Nagar Dhanori', 'Parande Nagar, Dhanori', 'Madhav Nagar, Dhanori'],
    'Kharadi': ['Tulaja Bhawani Nagar, Kharadi', 'Pandhari Nagar Kharadi', 'Yashwant Nagar Kharadi', 'Santipur, Kharadi'],
    'Kesnand': ['Kesnand Road', 'Phase 12 Kesnand'],
    'Pashan': ['Someshwarwadi, Pashan', 'Pashan Gaon, Pashan', 'Sutarwadi, Pashan'],
    'Baner': ['Baner Pashan Link Road', 'Ram Nagar Baner', 'Lalit Estate, Baner', 'Aundh Baner Link Road',
              'Baner Mahalunge Road'],
    'Sanghavi': ['New Sanghavi', 'Adarsh Nagar New Sanghavi'],
    'Wanawari': ['Jambhulkar Mala, Wanawari', 'Oxford Village, Wanawari'],
    'Manjri': ['Manjri BK', 'Manjri Greens Society', 'Mundhwa Manjari Road'],
    'Mohammed Wadi': ['Nyati County, Mohammed Wadi', 'Palace Orchard, Mohammed Wadi'],
    'Lohegaon': ['Sathe Nagar, Lohegaon', 'Sant Nagar Lohegaon', 'Moje Chal, Lohegaon',
                  'Lohegaon Wagholi Road', 'Lohegaon Road'],
    'Karvenagar': ['Girija Shankar Vihar, Karvenagar', 'Ganesh Nagar Karve Nagar', 'Karve Road'],
    'Katraj': ['Gokul Nagar Katraj', 'Mangdewadi, Katraj', 'Katrajnagar, Katraj']
}

# %%
with open('LocalitiesMerge/localityNameMerge_v3.json', 'w') as f:
    json.dump(localityNameMerge_v3, f, indent=4)

# %% [markdown]
# # Merge 4

# %%
localityNameMerge_v4 = {
    'Pimpri Chinchwad': [
        'Borade Vasti, Pimpri Chinchwad',
        'Bhujbal Vasti, Pimpri Chinchwad',
        'Vallabh Nagar, Pimpri Chinchwad',
        'Wakadkar Wasti, Pimpri Chinchwad',
        'Deepmala Society, Pimpri Chinchwad',
        'Pimpri Gaon, Pimpri Chinchwad',
        'Sangvi, Pimpri Chinchwad',
        'Bhagwan Nagar, Pimpri Chinchwad',
        'Sai Nagar Park, Pimpri Chinchwad',
        'Shahunagar, Pimpri Chinchwad',
        'Sukhwani Complex, Pimpri Chinchwad',
        'Kunj Colony, Pimpri Chinchwad',
        'Vrundawan Colony, Pimpri Chinchwad',
        'Shri Ram Colony, Pimpri Chinchwad',
        'Udhyog Nagar, Pimpri Chinchwad',
        'Dhore Nagar, Pimpri Chinchwad',
        'Postal Colony, Pimpri Chinchwad',
        'Pavana Nagar, Pimpri Chinchwad',
        'Raigad Colony, Pimpri Chinchwad',
        'Anand Nagar Chinchwad',
        'Dalvinagar Chinchwad',
        'Mohan Nagar Chinchwad'
    ],
    'Hinjewadi': [
        'Hinjewadi Village',
        'Shinde Nagar Hinjewadi Rajiv Gandhi Infotech Park',
        'Hinjewadi Wakad Road',
        'Phase 2 Hinjewadi',
        'Hinjewadi Phase 2 Road',
        'Bhatewara Nagar, Hinjewadi'
    ],
    'Kothrud': [
        'Jijai Nagar, Kothrud',
        'Gananjay Society, Kothrud',
        'Happy Colony, Kothrud',
        'Kothrud Bus Stand Road',
        'Gururaj Society Kothrud'
    ],
    'SP Infocity': [
        'Phursungi IT Park, SP Infocity',
        'SP Infocity'
    ],
    'Bakori': [
        'Bakori Road',
        'Bakori'
    ],
    'Manjri': [
        'Manjri',
        'Manjari Road',
        'Belekar Wasti, Manjri Budruk'
    ],
    'DP Road': [
        'New DP Road',
        'DP Road'
    ],
    'Aundh': [
        'Wireless Colony, Aundh',
        'Aundh Ravet BRTS Road',
        'Aundh Wakad Road',
        'Pushpak Park, Aundh',
        'Aundh Road',
        'Sanewadi, Aundh',
        'Baner CHS, Aundh',
        'Sakal Nagar, Aundh'
    ],
    'Viman Nagar': [
        'Mhada Colony-Viman Nagar, Viman Nagar',
        'Air Force Campus, Viman Nagar',
        'Ganga Hamlet, Viman Nagar'
    ],
    'Mundhwa': [
        'Jadhav Nagar Mundhwa',
        'Badhe Park, Mundhwa',
        'Sharad Nagar Mundhwa',
        'Mundhwa Industrial Area'
    ],
    'Moshi': [
        'Sant Nagar Moshi',
        'Sector Number 6 Moshi',
        'Sector Number 4 Moshi',
        'Sector Number 9 Moshi'
    ],
    'Koregaon Park': [
        'Clover Park View, Koregaon Park',
        'Meera Nagar, Koregaon Park',
        'Ragvilas Society, Koregaon Park',
        'Fatima Nagar Koregaon Park Annexe',
        'Koregaon Park Road'
    ],
    'Chikhali': [
        'Ganesh Nagar Chikhali, Chikhali',
        'Shelarvasti, Chikhali',
        'Gitai Colony, Chikhali'
    ],
    'Bavdhan': [
        'Patil Nagar Bavdhan',
        'Siddharth Nagar Bavdhan',
        'Shindenagar Bavdhan',
        'Sunarwadi, Bavdhan',
        'Vaidehi Enclave, Bavdhan',
        'Siddhivinayak Vihar, Bavdhan'
    ],
    'Rahatni': [
        'Ram Nagar Rahatni',
        'Madhuban Colony Rahatni'
    ],
    'Hadapsar': [
        'Sade Satra Nali, Hadapsar',
        'Mahadeonagar, Hadapsar',
        'Ramtekadi, Hadapsar',
        'Satar Nagar, Hadapsar',
        'Shinde Vasti Hadapsar',
        'Tukaram Tupe Nagar, Hadapsar',
        'Suraksha Nagar, Hadapsar',
        'Hingane Mala, Hadapsar',
        'Udyog Nagar Hadapsar',
        'Shiv Nagar Hadapsar'
    ],
    'Kondhwa': [
        'Saibaba Nagar, Kondhwa',
        'Shreehans Nagar, Kondhwa',
        'Anthon Nagar, Kondhwa Budruk',
        'Sainagar Kondhwa Budruk',
        'Rajiv Gandhi Nagar Kondhwa Budruk'
    ],
    'Wakad': [
        'Yamuna Nagar Wakad',
        'Swami Vivekanand Nagar Wakad',
        'Wakad Road',
        'New Wakad Hinjewadi Link Road'
    ],
    'MIDC': [
        'MIDC',
        'Talegaon MIDC Road'
    ],
    'Alandi': [
        'Alandi Road',
        'Chakan Alandi Road',
        'Indryani Nagar, Alandi',
        'Vadgaon Alandi'
    ]
}

# %%
with open('LocalitiesMerge/localityNameMerge_v4.json', 'w') as f:
    json.dump(localityNameMerge_v4, f, indent=4)

# %% [markdown]
# # Merge 5

# %%
localityNameMerge_v5 = {
    # Kothrud is the main area; very low–count sublocalities are merged into it.
    "Kothrud": [
        "Rambaug Colony, Kothrud",
        "Mahatma Society, Kothrud",
        "Datta Nagar Kothrud",
        "Chintamani Paradise, Kothrud",
        "Shastri Nagar Kothrud"
    ],
    # The Manjri entries
    "Manjri": [
        "Manjri, Manjri Budruk"
    ],
    # Baner: small subareas in Baner are merged into the main Baner area.
    "Baner": [
        "Samarth Colony Baner",
        "Dasar, Baner",
        "Vasant Vihar, Baner",
        "Madhavbaug Society Baner"
    ],
    # Balewadi: a small “Patil Nagar Balewadi” variant is merged here.
    "Balewadi": [
        "Patil Nagar Balewadi"
    ],
    # Aundh: minor variants are clubbed with Aundh.
    "Aundh": [
        "Rohan Nilay, Aundh",
        "Marutirao Gaikwad Nagar, Aundh",
        "Aundhe"
    ],
    # Hinjewadi (the central area) – keep the major “Hinjewadi” entry separate but merge very low–count variants.
    "Hinjewadi": [
        "Hinjewadi Village",
        "Hinjewadi Wakad Road",
        "Hinjewadi Phase 2 Road"
    ],
    # The Rajiv Gandhi Infotech Park entries in Hinjewadi (each around 100) might be seen as one campus.
    "Hinjewadi Rajiv Gandhi Infotech Park": [
        # "Phase 1 Hinjewadi Rajiv Gandhi Infotech Park",
        # "Phase 3 Hinjewadi Rajiv Gandhi Infotech Park",
        "Hinjewadi Rajiv Gandhi Infotech Park, Hinjewadi"
    ],
    # Kondhwa: here the very low–count “Kausar Baugh” (and a misspelled variant) and a road name are merged into Kondhwa.
    "Kondhwa": [
        "Kausar Baugh",
        "Kondhawe Dhawade",
        "Kondhwa Saswad Road",
        "Mallik Nagar, Kondhwa"
    ],
    # Katraj: even though “Katraj Kondhwa Road” contains two locality names, its count is low so we may map it into Katraj.
    "Katraj": [
        "Katraj Kondhwa Road"
    ],
    # Kalyani Nagar: merge a “New” version and a complex name into the parent.
    "Kalyani Nagar": [
        "New Kalyani Nagar",
        "Marigold complex, Kalyani Nagar"
    ],
    # Fursungi: a very low–count variant is merged into Fursungi.
    "Fursungi": [
        "Ganga Nagar Fursungi"
    ],
    # Within the many Pimpri Chinchwad–tagged names, we might decide only to club those with very low counts.
    # For example, a “Chikhali” variant appears in two forms.
    "Chikhali, Pimpri Chinchwad": [
        "Chikhali Pimpri Chinchwad"
    ],
    # Variants that mention “Pimple Nilakh” but with almost negligible counts can be merged
    "Pimple Nilakh, Pimpri Chinchwad": [
        "Patil Nagar Pimple Nilakh",
        "Kranti Nagar Pimple Nilakh"
    ],
    # Then a “catch‐all” for other very low–count Pimpri Chinchwad variants that do not have their own high count:
    "Pimpri Chinchwad - Other": [
        # "Dapodi, Pimpri Chinchwad",
        "Old Sangvi, Pimpri Chinchwad",
        "Roseland Residency, Pimpri Chinchwad",
        "Nehru Nagar, Pimpri Chinchwad",
        "Chinchwad Gaon, Pimpri Chinchwad",
        "Tupe Vasti, Pimpri Chinchwad"
    ],
    # And you might want to “normalize” a shorthand name:
    "Pimpri Chinchwad": [
        "Pimpri"
    ],
    # Vadgaon variants – group the BK and Budruk variants
    "Vadgaon": [
        "Vadgaon BK",
        "Kudale Baug, Vadgaon Budruk",
        "Jadhav Nagar Vadgaon Budruk"
    ],
    # Dhankawadi: merge a road variant into it.
    "Dhankawadi": [
        "Gulab Nagar, Dhankawadi"
    ],
    # Jambhul: merge the road variant.
    "Jambhul": [
        "Jambhulwadi Road"
    ],
    # A small spelling variation for Rahatani.
    "Rahatani": [
        "Rahatni"
    ],
    # Bibwewadi: merge two very low–count colony names.
    "Bibwewadi": [
        "Mitha Nagar, Bibvewadi",
        "Sangam Society, Bibvewadi"
    ],
    # Lullanagar: merge a related colony.
    "Lullanagar": [
        "Parsi Colony Lullanagar"
    ],
    # Tingre Nagar: merge two very low–count variants.
    "Tingre Nagar": [
        "Indira Nagar Tingre Nagar",
        "Subhash Nagar Tingre Nagar"
    ],
    # Ghorpadi: merge a “road” variant.
    "Ghorpadi": [
        "Ghorpadi Road"
    ],

    "Lonavala": [
        "Maval, Lonavala",
    ],

    "Sinhagad Road": [
        "Anand Nagar, Sinhagad Road"
    ]
}

# %%
with open('LocalitiesMerge/localityNameMerge_v5.json', 'w') as f:
    json.dump(localityNameMerge_v5, f, indent=4)
